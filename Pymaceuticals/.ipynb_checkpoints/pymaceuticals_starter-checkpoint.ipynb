# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
merge_df.rename(columns={'Age_months':'Age (Months)', 'Weight (g)':'Weight (Grams)', 'Timepoint':'Time (Days)'}, inplace=True)
# Display the data table for preview
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age (Months)  Weight (Grams)  Time (Days)  \
# 0        k403     Ramicane  Male            21              16            0
# 1        k403     Ramicane  Male            21              16            5
# 2        k403     Ramicane  Male            21              16           10
# 3        k403     Ramicane  Male            21              16           15
# 4        k403     Ramicane  Male            21              16           20
# ...       ...          ...   ...           ...             ...          ...
# 1888     z969     Naftisol  Male             9              30           25
# 1889     z969     Naftisol  Male             9              30           30
# 1890     z969     Naftisol  Male             9              30           35
# 1891     z969     Naftisol  Male             9              30           40
# 1892     z969     Naftisol  Male             9              30           45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
total_mice = merge_df['Mouse ID'].nunique()
print(f'Total Mice: {total_mice}')
# Out:
# Total Mice: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = merge_df[merge_df.duplicated(keep=False)]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age (Months)  Weight (Grams)  Time (Days)  \
# 908     g989     Propriva  Female            21              26            0
# 909     g989     Propriva  Female            21              26            0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908                45.0                 0
# 909                45.0                 0

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mice_df = merge_df.drop(merge_df[merge_df['Mouse ID'] == 'g989'].index)

clean_mice_df.head(910)
# Out:
#     Mouse ID Drug Regimen     Sex  Age (Months)  Weight (Grams)  Time (Days)  \
# 0       k403     Ramicane    Male            21              16            0
# 1       k403     Ramicane    Male            21              16            5
# 2       k403     Ramicane    Male            21              16           10
# 3       k403     Ramicane    Male            21              16           15
# 4       k403     Ramicane    Male            21              16           20
# ..       ...          ...     ...           ...             ...          ...
# 905     g867     Stelasyn  Female             9              25            5
# 906     g867     Stelasyn  Female             9              25           10
# 907     g867     Stelasyn  Female             9              25           15
# 921     h246     Ketapril    Male            13              30            0
# 922     h246     Ketapril    Male            13              30            5
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             45.000000                 0
# 1             38.825898                 0
# 2             35.014271                 1
# 3             34.223992                 1
# 4             32.997729                 1
# ..                  ...               ...
# 905           46.880749                 0
# 906           48.183402                 0
# 907           51.060419                 1
# 921           45.000000                 0
# 922           49.470417                 0
#
# [910 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_total_mice = clean_mice_df['Mouse ID'].nunique()
print(f'Total Clean Mice: {clean_total_mice}')
# Out:
# Total Clean Mice: 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

tumor_vol_mean = clean_mice_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
tumor_vol_median = clean_mice_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
tumor_vol_var = clean_mice_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
tumor_vol_sd = clean_mice_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
tumor_vol_sem = clean_mice_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()

tumor_vol_statistics_df = pd.DataFrame({'Tumor Vol (mm3): Mean': tumor_vol_mean, 
                                     'Median': tumor_vol_median, 
                                     'Variance': tumor_vol_var,
                                     'Std Dev': tumor_vol_sd,
                                     'SEM': tumor_vol_sem})
tumor_vol_statistics_df
# Out:
#               Tumor Vol (mm3): Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin                 40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin                  52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol                 52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril                  55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol                  54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo                   54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva                  52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane                  40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn                  54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol                 53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
agg_stats = clean_mice_df.loc[:, ['Drug Regimen', 'Tumor Volume (mm3)']]
agg_stats_df = agg_stats.groupby('Drug Regimen').agg([np.mean, np.median, np.var, np.std, st.sem])
# Using the aggregation method, produce the same summary statistics in a single line
agg_stats_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
regimen_count = clean_mice_df['Drug Regimen'].value_counts()

plt.barh(regimen_count.index, regimen_count, color='skyblue', alpha=1, align='center')

plt.title('Drug Regimen Measurements')
plt.xlabel('Regiment Count')
plt.ylabel('Drug Type')

plt.tight_layout()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
regimen_count.plot.barh(stacked=True, color='skyblue', align='center');

plt.title('Drug Regimen Measurements')
plt.xlabel('Regiment Count')
plt.ylabel('Drug Type')
# Out:
# Text(0, 0.5, 'Drug Type')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_groups = clean_mice_df.groupby('Sex')
gender_distribution = gender_groups['Drug Regimen'].count()
plot = gender_distribution.plot.pie(y='mass', title='Mice Gender Distribution', colors =['pink','skyblue'], autopct='%0.1f%%')
plt.ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = list(gender_distribution.index.values)
colors = ['pink', 'skyblue']
plt.pie(gender_distribution, labels=labels, colors=colors, autopct='%0.1f%%', shadow=True)

plt.title('Mice Gender Distribution')
plt.ylabel('Gender')
plt.tight_layout()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
treatment_regimen = clean_mice_df[clean_mice_df['Drug Regimen'].isin(['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])]
treatment_regimen
# Out:
#      Mouse ID Drug Regimen     Sex  Age (Months)  Weight (Grams)  Time (Days)  \
# 0        k403     Ramicane    Male            21              16            0
# 1        k403     Ramicane    Male            21              16            5
# 2        k403     Ramicane    Male            21              16           10
# 3        k403     Ramicane    Male            21              16           15
# 4        k403     Ramicane    Male            21              16           20
# ...       ...          ...     ...           ...             ...          ...
# 1868     z581    Infubinol  Female            24              25           25
# 1869     z581    Infubinol  Female            24              25           30
# 1870     z581    Infubinol  Female            24              25           35
# 1871     z581    Infubinol  Female            24              25           40
# 1872     z581    Infubinol  Female            24              25           45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1868           54.316407                 2
# 1869           56.286750                 2
# 1870           58.628399                 3
# 1871           60.053740                 3
# 1872           62.754451                 3
#
# [814 rows x 8 columns]

# %%
treatment_regimen_df = treatment_regimen[['Drug Regimen', 'Mouse ID', 'Time (Days)', 'Tumor Volume (mm3)']]
treatment_regimen_df
# Out:
#      Drug Regimen Mouse ID  Time (Days)  Tumor Volume (mm3)
# 0        Ramicane     k403            0           45.000000
# 1        Ramicane     k403            5           38.825898
# 2        Ramicane     k403           10           35.014271
# 3        Ramicane     k403           15           34.223992
# 4        Ramicane     k403           20           32.997729
# ...           ...      ...          ...                 ...
# 1868    Infubinol     z581           25           54.316407
# 1869    Infubinol     z581           30           56.286750
# 1870    Infubinol     z581           35           58.628399
# 1871    Infubinol     z581           40           60.053740
# 1872    Infubinol     z581           45           62.754451
#
# [814 rows x 4 columns]

# %%
# Start by getting the last (greatest) timepoint for each mouse
greatest_tp = treatment_regimen_df.sort_values(['Mouse ID'], ascending=False)
greatest_tp
# Out:
#      Drug Regimen Mouse ID  Time (Days)  Tumor Volume (mm3)
# 1872    Infubinol     z581           45           62.754451
# 1867    Infubinol     z581           20           51.807944
# 1863    Infubinol     z581            0           45.000000
# 1865    Infubinol     z581           10           50.478750
# 1866    Infubinol     z581           15           51.196304
# ...           ...      ...          ...                 ...
# 459     Infubinol     a203           25           56.793208
# 458     Infubinol     a203           20           55.173336
# 456     Infubinol     a203           10           51.852437
# 455     Infubinol     a203            5           48.508468
# 457     Infubinol     a203           15           52.777870
#
# [814 rows x 4 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merge_data_df = pd.merge(greatest_tp, clean_mice_df, on=('Mouse ID', 'Drug Regimen', 'Time (Days)', 'Tumor Volume (mm3)'), how = 'left')
merge_data_df = merge_data_df.sort_values(['Time (Days)'], ascending=False)
merge_data_df
# Out:
#     Drug Regimen Mouse ID  Time (Days)  Tumor Volume (mm3)     Sex  \
# 0      Infubinol     z581           45           62.754451  Female
# 64      Ceftamin     x822           45           61.386660    Male
# 500     Ceftamin     j296           45           61.849023  Female
# 746     Ramicane     a644           45           32.978522  Female
# 76      Ceftamin     x581           45           64.634949  Female
# ..           ...      ...          ...                 ...     ...
# 717    Capomulin     b128            0           45.000000  Female
# 716     Ceftamin     b447            0           45.000000    Male
# 714     Ceftamin     b487            0           45.000000  Female
# 616     Ceftamin     f436            0           45.000000  Female
# 185    Capomulin     t565            0           45.000000  Female
#
#      Age (Months)  Weight (Grams)  Metastatic Sites
# 0              24              25                 3
# 64              3              29                 3
# 500            24              30                 3
# 746             7              17                 1
# 76             19              28                 3
# ..            ...             ...               ...
# 717             9              22                 0
# 716             2              30                 0
# 714             6              28                 0
# 616             3              25                 0
# 185            20              17                 0
#
# [814 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
tumor_vol_data = []
    
for drug in treatment_regimen_df:
    quartiles = treatment_regimen_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    tumor_data = merge_data_df['Tumor Volume (mm3)']
    tumor_vol_data.append(tumor_data)
    
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
print(f"The lower quartile of tumor volume is: {lowerq}")
print(f"The upper quartile of  tumor volume is: {upperq}")
print(f"The interquartile range of  tumor volume is: {iqr}")
print(f"The the median of tumor volume is: {quartiles[0.5]}")

# Determine outliers using upper and lower bounds
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of tumor volume is: 40.2201707875
# The upper quartile of  tumor volume is: 50.356470630000004
# The interquartile range of  tumor volume is: 10.136299842500001
# The the median of tumor volume is: 45.0
# Values below 25.01572102375 could be outliers.
# Values above 65.56092039375001 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax = plt.subplots()
ax.set_title('Final Tumor Volume Across Regimens')
ax.set_xlabel('Drug Regimen')
ax.set_ylabel('Tumor Vol (mm3)')
ax.boxplot(tumor_vol_data,notch=1,sym='o')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = clean_mice_df.loc[clean_mice_df['Drug Regimen'] == 'Capomulin']
mouse_id = clean_mice_df.loc[clean_mice_df['Mouse ID'] == 't565']
plt.plot(mouse_id['Time (Days)'], mouse_id['Tumor Volume (mm3)'], marker = 'o', color = 'orange')
plt.xlabel('Time (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Mouse:t565 Capomulin Regimen')
# Out:
# Text(0.5, 1.0, 'Mouse:t565 Capomulin Regimen')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
tumor_vol_avg = pd.DataFrame(capomulin_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Tumor Volume(mm3) Average'})
tumor_vol_avg.head()
# Out:
#   Mouse ID  Tumor Volume(mm3) Average
# 0     s185                  34.559143
# 1     m601                  34.847470
# 2     x401                  36.182040
# 3     f966                  36.505973
# 4     r554                  36.509212

# %%
tumor_avg_merge = pd.merge(capomulin_df, tumor_vol_avg, on='Mouse ID')
final_tumor_avg_df = tumor_avg_merge[['Weight (Grams)', 'Tumor Volume(mm3) Average']].drop_duplicates()
final_tumor_avg_df.head()
# Out:
#     Weight (Grams)  Tumor Volume(mm3) Average
# 0               17                  34.559143
# 10              15                  36.182040
# 20              17                  34.847470
# 30              17                  36.505973
# 35              17                  39.887495

# %%
x = final_tumor_avg_df['Weight (Grams)']
y = final_tumor_avg_df['Tumor Volume(mm3) Average']
plt.scatter(x, y, facecolor='orange', alpha=0.5)
plt.xlabel("Weight (Grams)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume vs Mouse Weight')
# Out:
# Text(0.5, 1.0, 'Average Tumor Volume vs Mouse Weight')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
